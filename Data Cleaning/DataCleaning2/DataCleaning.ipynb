# %%
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('messy_ecommerce_data.csv')
data
# Out:
#   transaction_id     customer_name   join_date purchase_amount  \
# 0        TXN-101    Sarah Connor    2023-01-15         $150.00
# 1        TXN-102         mike ross  02/20/2023            89.5
# 2        TXN-103    Harvey Specter  2023-03-01          -45.00
# 3        TXN-104       Rachel Zane  2023-03-05             NaN
# 4        TXN-105        Louis Litt  2023-03-12           210.0
# 5        TXN-105        Louis Litt  2023-03-12           210.0
# 6        TXN-106               NaN  2023/04/01          120.75
# 7        TXN-107     Donna Paulsen  2023-04-10       999999.00
#
#          category     status
# 0     Electronics  Completed
# 1       clothings  COMPLETED
# 2     Electronics    Pending
# 3  Home & Kitchen  cancelled
# 4     Electronics  Completed
# 5     Electronics  Completed
# 6       Clothings  COMPLETED
# 7  home & kitchen  Completed

# %%
data.columns
# Out:
# Index(['transaction_id', 'customer_name', 'join_date', 'purchase_amount',
#        'category', 'status'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   transaction_id   8 non-null      object
#  1   customer_name    7 non-null      object
#  2   join_date        8 non-null      object
#  3   purchase_amount  7 non-null      object
#  4   category         8 non-null      object
#  5   status           8 non-null      object
# dtypes: object(6)
# memory usage: 516.0+ bytes

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# dtype: bool

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 6    False
# 7    False
# dtype: bool

# %%
data
# Out:
#   transaction_id     customer_name   join_date purchase_amount  \
# 0        TXN-101    Sarah Connor    2023-01-15         $150.00
# 1        TXN-102         mike ross  02/20/2023            89.5
# 2        TXN-103    Harvey Specter  2023-03-01          -45.00
# 3        TXN-104       Rachel Zane  2023-03-05             NaN
# 4        TXN-105        Louis Litt  2023-03-12           210.0
# 6        TXN-106               NaN  2023/04/01          120.75
# 7        TXN-107     Donna Paulsen  2023-04-10       999999.00
#
#          category     status
# 0     Electronics  Completed
# 1       clothings  COMPLETED
# 2     Electronics    Pending
# 3  Home & Kitchen  cancelled
# 4     Electronics  Completed
# 6       Clothings  COMPLETED
# 7  home & kitchen  Completed

# %%
data['purchase_amount'][0] = 150

# %%
data['purchase_amount'] = data['purchase_amount'].astype(float)

# %%
data.drop(7, inplace=True)

# %%
data['purchase_amount'].fillna(data['purchase_amount'].mean(), inplace=True)

# %%
data['purchase_amount'] = abs(data['purchase_amount'])

# %%
data['join_date'] = pd.to_datetime(data['join_date'], format='mixed')

# %%
data.dropna(inplace=True)

# %%
data['customer_name'] = data['customer_name'].str.title()
data['category'] = data['category'].str.lower()
data['status'] = data['status'].str.upper()

# %%
data['category'][1] = 'clothing'

# %%
data = data.drop(columns=(1, 'category'))

# %%
data
# Out:
#   transaction_id     customer_name  join_date  purchase_amount  \
# 0        TXN-101    Sarah Connor   2023-01-15           150.00
# 1        TXN-102         Mike Ross 2023-02-20            89.50
# 2        TXN-103    Harvey Specter 2023-03-01            45.00
# 3        TXN-104       Rachel Zane 2023-03-05           105.05
# 4        TXN-105        Louis Litt 2023-03-12           210.00
#
#          category     status
# 0     electronics  COMPLETED
# 1        clothing  COMPLETED
# 2     electronics    PENDING
# 3  home & kitchen  CANCELLED
# 4     electronics  COMPLETED
